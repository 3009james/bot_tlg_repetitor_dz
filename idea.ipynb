# %% [markdown]
# Привет, работай пока в папке E:\DISERTATION\response\code\tlg_bot_dz. Я занимаюсь репетиторством. Преподаю машинное обучение, нейронные сети, python, c++. Теперь хочу сделать телеграмм бота, которого потом загружу на VPS сервер, и который смогу редактировать, сначала локально, потом пушить на git, и пулить на VPS. Идея бота следующая:
# Бот для тестирования по темам. Будет в виде приложения телеграмм. В темно синем цветовом формате. У меня есть админка, если я открываю бота.
# То есть, например у меня три ученика:
# 1. Обучаю C++.
# 2. Python
# 3. Математика
# Данный бот, пока будет работать через api https://routerai.ru/. Далее, я провел занятие с учеником, по результатам которог у меня формируется блокнот ipynb. Он содержит материал урока. В итоге, у каждого ученика уже собран набор блокнотов, с материалами которые мы с ним прошли.
# Далее, я по завершению занятия, загружаю блокнот боту. Бот изучает его, и заносит себе в базу данных. В итоге у бота есть на каждого ученика весь материал, что с ним изучили. Тут надо еще подумать, как максимально снизить объем памяти которые занимают материалы, чтобы боту было легче, но при этом помнил или мог вспомнить.
# Бот, на каждый день генерирует в 00:00 10 заданий по пройденному материалу по уровню сложности, для каждого ученика. В админке я сам добавляю ученика которому сгенерирует задания. Любой другой, который откроет бота, не сможет увидеть задания, только отправить заявку. Если ученик новый, он отправляет заявку, я через админку добавляю его в бота, и бот сразу генерирует задания на день по уровню сложности. Если ученик не новый, то ежедневно автоматически генерируются задания.
# То есть, ученик заходит в бота, бот приветствует ученика, пишет Здравствуйте, имя ученика и его фото. Ниже кнопка "Пройти обучение". Выбор режима тестирование или вручную. И далее выбор сложности, легко, среднее, сложно.
# При выборе, режима тестирование и уровня сложности, бот открывает сгенерированные задания в форме тестирования по одному. То есть на экране у ученика, текст одного задания и варианты ответа (4-5 штук) в виде кнопок. После ответа, выдается правильный ответ, ученик может его посмотреть и потом нажать следующее задание, после которого открывается следующее задание.
# Пока так, следующий режим позже реализуем.

# %% [markdown]
# Привет, я делаю телеграмм бота "Я занимаюсь репетиторством. Преподаю машинное обучение, нейронные сети, python, c++. Теперь хочу сделать телеграмм бота, которого потом загружу на VPS сервер, и который смогу редактировать, сначала локально, потом пушить на git, и пулить на VPS. Идея бота следующая:
# Бот для тестирования по темам. Будет в виде приложения телеграмм. В темно синем цветовом формате. У меня есть админка, если я открываю бота.
# То есть, например у меня три ученика:
# 1. Обучаю C++.
# 2. Python
# 3. Математика
# Данный бот, пока будет работать через api https://routerai.ru/.
# Далее, я провел занятие с учеником, по результатам которог у меня формируется блокнот ipynb. Он содержит материал урока. В итоге, у каждого ученика уже собран набор блокнотов, с материалами которые мы с ним прошли.
# Далее, я по завершению занятия, загружаю блокнот боту. Бот изучает его, и заносит себе в базу данных. В итоге у бота есть на каждого ученика весь материал, что с ним изучили.
# Тут надо еще подумать, как максимально снизить объем памяти которые занимают материалы, чтобы боту было легче, но при этом помнил или мог вспомнить.
# Бот, на каждый день генерирует в 00:00 10 заданий по пройденному материалу по уровню сложности, для каждого ученика.
# В админке я сам добавляю ученика которому сгенерирует задания. Любой другой, который откроет бота, не сможет увидеть задания, только отправить заявку. Если ученик новый, он отправляет заявку, я через админку добавляю его в бота, и бот сразу генерирует задания на день по уровню сложности. Если ученик не новый, то ежедневно автоматически генерируются задания.
# То есть, ученик заходит в бота, бот приветствует ученика, пишет Здравствуйте, имя ученика и его фото. Ниже кнопка "Пройти обучение". Выбор режима тестирование или вручную. И далее выбор сложности, легко, среднее, сложно.
# При выборе, режима тестирование и уровня сложности, бот открывает сгенерированные задания в форме тестирования по одному. То есть на экране у ученика, текст одного задания и варианты ответа (4-5 штук) в виде кнопок. После ответа, выдается правильный ответ, ученик может его посмотреть и потом нажать следующее задание, после которого открывается следующее задание. Следующий режим позже.". Данный бот находится в D:\multiagent\RL_and_PPO\tlg_bot_dz, поэтому работай там. Проанализируй бота. Дальше буду говорить тебе как его исправить.

# %% [markdown]
# Нужно чтобы темы, которые ему даю, блокноты я скидывал через админку. Там предоставляется выбор, какому ученику отнести данный материал.
# И далее, я через админку, для каждого ученика могу выбрать темы на которые будет генерировать уроки, и тогда бот будет далее генерировать в соответствии с данными темами. Я выбрал темы и нажимаю генерировать, он генерирует для данного ученика, в соответствии с выбранными темами, для каждой уровня сложности по 10 задач. А затем он просто каждый день в 00:00 генерирует задачи. В 9 утра по Москве отправляет ученикам напоминание, что новые задачи выложены.

# %% [markdown]
# Нужно убрать кнопки из бота все, оставить только открыть приложение.
# При открытии приложения, мною, администратором, у меня открываться должна панель администратора, и весь функционал пусть будет там.

# %% [markdown]
# Отлично, заработало. Проблема была в том что я push не делал а pull только. Ты мне напоминай.
# Теперь редактируем дальше. Вот открылась админ панель.
# Убери все кнопки что там есть.
# В админ панели, будет приветствие меня.
# Будет кнопка виды занятий. У меня в боте сейчас будет три вида занятий:
# 1. C++.
# 2. Python
# 3. Математика
# При нажатии на любой вид занятия, открывается окно, где есть кнопка: загрузить материал (при нажатии на которую могу загрузить блокнот ipynb), и ИИ анализирует все загруженные материалы с учетом нового и автоматически разбивает на темы которые там есть. Далее там есть кнопка выбрать темы. При нажатии на которую, открывается окно, в котором могу выбрать темы по которым будет генерироваться задания. После выбора тем, есть еще кнопка сгенерировать задания на сутки, при нажатии генериуются задания, на этот вид занятия, с учетом выбранных тем, пройденного материала и на каждый уровень сложности по 10 заданий, ответы на задания, и решения. После того как сгенерировано, есть кнопка посмотреть задания на сутки, там предлагается три вида сложности, нажимаю на любой и могу просмотреть вопросы, варианты ответа и правильные ответы. Далее там же еще могу выбрать режим генерации, вручную это когда я сам буду заходить и генерировать, либо автоматический, когда будет автоматически генерироваться и выбрать время генерации. Также, для вида занятий могу выбрать учеников. Есть для этого кнопка закрепить ученика за видом занятия. Там могу выбрать из всех учеников, которые заявки я согласовал, любых учеников, и именно по этому виду занятия у ученика будут задачи.
#
# У ученика. Ученик когда открывает бота, первый раз, приветствие, его имя и фото. Описание бота. Потом отправить заявку для работы с ботом. Мне приходит от бота уведомление про ученика, что хочет учавствовать, и я могу подтвердить или отменить. Если подтверждаю, ученик заноситься в БД учеников, бот запоминает его. После у ученика будет написано, занятия обновлены время и дата по москве. И ниже кнопка начать. Предлагается выбрать режим, вручную или тестирование. Пока разберем тестирование. Он нажимает тестирование, предлагается выбор уровня сложности, низкий, средний и высокий. Выбирает уровень и открывается первое задание, и от 4 до 5 вариантов ответа на задание. Он нажимает на нужный ответ, высвечивается правильный ответ, и если решение есть то может посмотреть решение на него нажать. Далее стрелку вправо, следующее задание. И так далее. Может возращаться к любому вопросу. И, если захочет заново пройти тестирование, нажмет начать и заново пройдет, то есть мы его не ограничиваем. Начать тестирование только сможет после того как я добавлю его в вид занятия.
# Должна быть система, которая экономит токены.

# %% [markdown]
# Давай чуть упростим, пусть материал который ему даю по урокам будут txt, word документ или pdf, не ipynb.

# %% [markdown]
# Теперь смотри, давай уберем режим автоматической генерации заданий. И убери у ученика выбор режима тестирование и в ручную, будет только один, поэтому нажимает начать, выбирает уровень сложности и поехали.
# Задания буду генерировать новые либо я с админ панели, сколько угодно и в любое время, и теперь под конкретный уровень сложности.
# Либо ученик. То есть, ученик зашел, а там новых заданий нет, то он нажимает кнопку, новые задачи, выбирает уровень сложности и тогда, генерируются задания для данного уровня сложности, но с анимацией, чтобы ученик видел, что новые задачи создаются а не зависло.
# Если он зашел, там есть задания, он просто проходит их также, и далее ему доступна кнопка новые задания только после 7:00 утра следующего дня. И может также генерировать, если доступно, если нет, то может только проходить/перепроходить крайние задания которые есть.
# Потом, измени генерацию заданий, для вида занятий python и c++, в плане, пусть при генерации 10 заданий, на любом уровне сложности только три вопроса будут в форме вопроса тестового, типа какая команда, или какой оператор отвечает или другие и варианты ответа, а остальные по 7 вопросов, будут практическими прям, типа написать программу которая будет делать то, то. И далее, под практические вопросы будет окно ввода кода, где может вручную написать, или написать у себя в ide и скопировать код на проверку, который смотрит через router ai, правильно ли выполнена задача. И выдает ответ, типа правильно, рекомендации если есть по улучшению, или неправильно, и выдавать готовый код.
# Если под математику, то там также 3 теоретических вопроса, с вариантами ответа и 7 практических, где также варианты ответа, ответ на задачи, и при выборе ответа можно выбрать посмотреть решение.
# Если забыл проект - вспомни, проанализировав заново что есть.

# %% [markdown]
# mkdir -p /opt/projects
# cd /opt/projects
# cd /opt/projects/bot_tlg_repetitor_dz
#
# git clone https://github.com/3009james/bot_tlg_repetitor_dz.git
#
# 3009james
#
# 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
#
# cd D:\multiagent\RL_and_PPO\tlg_bot_dz
# git add Dockerfile docker-compose.yml .dockerignore README.md
# git commit -m "Add Docker production deployment"
# git push
#
#
# sk-GRrr3SnBcUsEKuVrz7iavZ1sWOveVfT8
#
# docker compose up -d --build bot api webapp
# docker compose up -d --build --force-recreate api webapp bot
#
# docker compose ps
# docker compose logs -f bot
